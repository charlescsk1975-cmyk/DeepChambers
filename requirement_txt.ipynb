# %% [markdown]
# <a href="https://colab.research.google.com/github/charlescsk1975-cmyk/DeepChambers/blob/main/requirement_txt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
streamlit>=1.32
scikit-learn>=1.3
joblib>=1.3
pandas>=2.0
numpy>=1.24
